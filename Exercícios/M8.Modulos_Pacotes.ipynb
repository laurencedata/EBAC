# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 08** | Módulos e pacotes
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>from / import / as;</li>
#   <li>Módulo;</li>
#   <li>Pacote;</li>
#   <li>Baixando pacotes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 0\. Preparação do ambiente

# %% [markdown]
# Neste exercício vamos utilizar a base de dados de ações da bolsa de valores dos EUA, a Dow Jones. Os dados estão disponíveis para *download* neste [link](https://archive.ics.uci.edu/ml/datasets/Dow+Jones+Index). Vamos utilizar o pacote `wget` para fazer o *download* dos dados.

# %% [markdown]
#  - Instalando o pacote `wget` na versão 3.2.

# %%
# !pip install wget==3.2
# Out:
# Requirement already satisfied: wget==3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
#  - Fazendo o download dos dados no arquivo compactado `dados.zip`.

# %%
import wget

wget.download(url='https://archive.ics.uci.edu/ml/machine-learning-databases/00312/dow_jones_index.zip', out='./dados.zip')
# Out:
# './dados.zip'

# %% [markdown]
#  - Descompactando os `dados` na pasta dados com o pacote nativo `zipfile`.

# %%
import zipfile

with zipfile.ZipFile('./dados.zip', 'r') as fp:
  fp.extractall('./dados')

# %% [markdown]
# Verifique a pasta dados criada, ela deve conter dois arquivos:
#
#  - **dow_jones_index.data**: um arquivo com os dados;
#  - **dow_jones_index.names**: um arquivo com a descrição completa dos dados.
#
# É possível observar que o arquivo de dados é um arquivo separado por virgulas, o famoso `csv`. Vamos renomear o arquivo de dados para que ele tenha a extensão `csv` com o pacote nativo `os`.

# %% [markdown]
# - Renomeando o arquivo com o pacote nativo `os`.

# %%
import os

os.rename('./dados/dow_jones_index.data', './dados/dow_jones_index.csv')

# %% [markdown]
# Pronto! Abra o arquivo e o Google Colab irá apresentar uma visualização bem legal dos dados.

# %% [markdown]
# ---

# %% [markdown]
# ## 1\. Pandas

# %% [markdown]
# Para processar os dados, vamos utilizar o pacote `pandas` na versão `1.1.5`. A documentação completa por ser encontrada neste [link](https://pandas.pydata.org/docs/)

# %%
# !pip install pandas==1.1.5
# Out:
# Collecting pandas==1.1.5
#   Downloading pandas-1.1.5.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 5.9 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/laurenceribeiro/Library/Python/3.11/lib/python/site-packages (from pandas==1.1.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas==1.1.5) (2023.3)
# Requirement already satisfied: numpy>=1.15.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas==1.1.5) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/laurenceribeiro/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7.3->pandas==1.1.5) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pandas (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1164 lines of output]
#       <string>:19: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#       <string>:45: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       <string>:454: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-universal2-cpython-311
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/_typing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/_version.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/_testing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       copying pandas/testing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/compat
#       copying pandas/compat/_optional.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/aggregation.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/construction.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/indexers.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/shared_docs.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/strings.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/util
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/orc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       copying pandas/io/spss.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tseries
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_optional_dependency.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_aggregation.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_lib.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/arrays
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/api
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/errors
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       copying pandas/_config/config.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       copying pandas/_config/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       copying pandas/_config/display.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       copying pandas/_config/localization.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       copying pandas/_config/dates.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_config
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/compat/numpy
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/reshape
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       copying pandas/core/tools/times.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/tools
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/util
#       copying pandas/core/util/numba_.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/util
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/transforms.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/array_algos
#       copying pandas/core/array_algos/masked_reductions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/array_algos
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/dtypes
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/groupby
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/internals
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/parsing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/computation
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/ewm.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/rolling.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/indexers.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/numba_.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       copying pandas/core/window/expanding.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/window
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_arrow_utils.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/string_.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/boolean.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/masked.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       copying pandas/core/arrays/_mixins.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/array_ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/roperator.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/methods.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/dispatch.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/invalid.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/docstrings.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/mask_ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       copying pandas/core/ops/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/ops
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/sparse
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/extension.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/indexes
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/accessor.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/scipy_sparse.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/dtype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/array.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/core/arrays/sparse
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/info.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_openpyxl.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlrd.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_pyxlsb.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_odswriter.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_util.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_odfreader.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlwt.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       copying pandas/io/excel/_xlsxwriter.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/excel
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/json
#       copying pandas/io/json/_json.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/json
#       copying pandas/io/json/_normalize.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/json
#       copying pandas/io/json/_table_schema.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/json
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/sas
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/clipboard
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_block_internals.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_alter_axes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_reductions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_timeseries.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_cumulative.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_timezones.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_operators.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_analytics.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_io.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_datetime_values.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_internals.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_ufunc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_combine_concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/series
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot_multilevel.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_get_dummies.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       copying pandas/tests/reshape/test_crosstab.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/reshape
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_time.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_timedelta.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_datetime.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       copying pandas/tests/tools/test_to_numeric.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tools
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_string.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_boolean.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       copying pandas/tests/extension/test_numpy.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/extension
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_deprecated.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/resample
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_nonkeyword_arguments.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_show_versions.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_produces_warning.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_numba.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_doc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_kwarg.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       copying pandas/tests/util/test_assert_almost_equal.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/util
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/config
#       copying pandas/tests/config/test_localization.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/config
#       copying pandas/tests/config/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/config
#       copying pandas/tests/config/test_config.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/config
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_parquet.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_fsspec.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_compression.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_date_converters.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_pickle.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_orc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_clipboard.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_stata.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_html.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_gcs.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_sql.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_gbq.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_feather.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_spss.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/generate_legacy_storage_files.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       copying pandas/tests/io/test_s3.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/io
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tseries
#       copying pandas/tests/tseries/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/tseries
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_block_internals.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_alter_axes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/conftest.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_axis_select_reindex.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_timeseries.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_query_eval.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_cumulative.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_timezones.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_sort_values_level_as_str.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_operators.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_subclass.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_reshape.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_analytics.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_repr_info.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_nonunique_indexes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_validate.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_api.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_arithmetic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_combine_concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_dtypes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       copying pandas/tests/frame/test_to_csv.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/frame
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_inference.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_common.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_missing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_generic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_concat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       copying pandas/tests/dtypes/test_dtypes.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/dtypes
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/groupby
#       copying pandas/tests/groupby/test_timegrouper.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/groupby
#       copying pandas/tests/groupby/test_grouping.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/groupby
#       copying pandas/tests/groupby/test_counting.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/groupby
#       copying pandas/tests/groupby/test_value_counts.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/groupby
# ...
#       copying pandas/tests/indexes/multi/test_get_set.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_monotonic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_isin.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_drop.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_duplicates.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_partial_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_lexsort.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       copying pandas/tests/indexes/multi/test_reindex.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/multi
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_searchsorted.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_shift.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_factorize.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_to_timestamp.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_scalar_compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_astype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_formats.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_setops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_partial_slicing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_monotonic.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_fillna.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_tools.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_asfreq.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       copying pandas/tests/indexes/period/test_period_range.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/period
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_astype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_formats.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_category.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_fillna.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_map.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       copying pandas/tests/indexes/categorical/test_reindex.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/categorical
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/numeric
#       copying pandas/tests/indexes/numeric/test_astype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/numeric
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_shift.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_misc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_insert.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_pickle.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_to_period.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_date_range.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_timezones.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetimelike.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_snap.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_scalar_compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_delete.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_astype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_formats.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_setops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_datetime.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_partial_slicing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_fillna.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_map.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       copying pandas/tests/indexes/datetimes/test_ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/datetimes
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_searchsorted.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_shift.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_insert.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_constructors.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_join.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_scalar_compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_indexing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_delete.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_astype.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_formats.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_setops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_partial_slicing.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_fillna.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_ops.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       copying pandas/tests/indexes/timedeltas/test_timedelta_range.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/tests/indexes/timedeltas
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs/window
#       copying pandas/_libs/window/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs/window
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs/tslibs
#       copying pandas/_libs/tslibs/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/_libs/tslibs
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/misc.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/hist.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/compat.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/boxplot.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/style.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/tools.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/converter.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/core.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       copying pandas/plotting/_matplotlib/timeseries.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/plotting/_matplotlib
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/api/indexers
#       copying pandas/api/indexers/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/api/indexers
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/api/types
#       copying pandas/api/types/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/api/types
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/api/extensions
#       copying pandas/api/extensions/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/pandas/api/extensions
#       creating build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats/templates
#       copying pandas/io/formats/templates/html.tpl -> build/lib.macosx-10.9-universal2-cpython-311/pandas/io/formats/templates
#       UPDATING build/lib.macosx-10.9-universal2-cpython-311/pandas/_version.py
#       set build/lib.macosx-10.9-universal2-cpython-311/pandas/_version.py to '1.1.5'
#       running build_ext
#       building 'pandas._libs.algos' extension
#       creating build/temp.macosx-10.9-universal2-cpython-311
#       creating build/temp.macosx-10.9-universal2-cpython-311/pandas
#       creating build/temp.macosx-10.9-universal2-cpython-311/pandas/_libs
#       clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -DNPY_NO_DEPRECATED_API=0 -I./pandas/_libs -Ipandas/_libs/src/klib -I/private/var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/pip-build-env-trc_x2d_/overlay/lib/python3.11/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.11/include/python3.11 -c pandas/_libs/algos.c -o build/temp.macosx-10.9-universal2-cpython-311/pandas/_libs/algos.o -Wno-error=unreachable-code
#       pandas/_libs/algos.c:788:10: fatal error: 'numpy/arrayobject.h' file not found
#       #include "numpy/arrayobject.h"
#                ^~~~~~~~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# Failed to build pandas
# ERROR: Could not build wheels for pandas, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Vamos importar o pacote com o apelido (alias) `pd`.

# %%
import pandas as pd

# %% [markdown]
# Estamos prontos para ler o arquivo.

# %%
df = pd.read_csv('./dados/dow_jones_index.csv')

# %% [markdown]
# O pandas trabalha com o conceito de dataframe, uma estrutura de dados com muitos métodos e atributos que aceleram o processamento de dados. Alguns exemplos:

# %% [markdown]
#  - Visualizando as `n` primeiras linhas:

# %%
df.head(n=10)
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
# 5        1    AA  2/11/2011  $17.33  $17.48  $16.97  $17.37  114691279
# 6        1    AA  2/18/2011  $17.39  $17.68  $17.28  $17.28   80023895
# 7        1    AA  2/25/2011  $16.98  $17.15  $15.96  $16.68  132981863
# 8        1    AA   3/4/2011  $16.81  $16.94  $16.13  $16.58  109493077
# 9        1    AA  3/11/2011  $16.58  $16.75  $15.42  $16.03  114332562
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0              3.792670                                 NaN
# 1             -4.428490                            1.380223
# 2             -2.470660                          -43.024959
# 3              1.638310                            9.355500
# 4              5.933250                            1.987452
# 5              0.230814                          -25.712195
# 6             -0.632547                          -30.226696
# 7             -1.766780                           66.177694
# 8             -1.368230                          -17.663150
# 9             -3.317250                            4.419900
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# 1            239655616.0          $16.19           $15.79
# 2            242963398.0          $15.87           $16.13
# 3            138428495.0          $16.18           $17.14
# 4            151379173.0          $17.33           $17.37
# 5            154387761.0          $17.39           $17.28
# 6            114691279.0          $16.98           $16.68
# 7             80023895.0          $16.81           $16.58
# 8            132981863.0          $16.58           $16.03
# 9            109493077.0          $15.95           $16.11
#
#    percent_change_next_weeks_price  days_to_next_dividend  \
# 0                        -4.428490                     26
# 1                        -2.470660                     19
# 2                         1.638310                     12
# 3                         5.933250                      5
# 4                         0.230814                     97
# 5                        -0.632547                     90
# 6                        -1.766780                     83
# 7                        -1.368230                     76
# 8                        -3.317250                     69
# 9                         1.003130                     62
#
#    percent_return_next_dividend
# 0                      0.182704
# 1                      0.187852
# 2                      0.189994
# 3                      0.185989
# 4                      0.175029
# 5                      0.172712
# 6                      0.173611
# 7                      0.179856
# 8                      0.180941
# 9                      0.187149

# %% [markdown]
#  - Visualizando o nome das colunas:

# %%
df.columns.to_list()
# Out:
# ['quarter',
#  'stock',
#  'date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'percent_change_price',
#  'percent_change_volume_over_last_wk',
#  'previous_weeks_volume',
#  'next_weeks_open',
#  'next_weeks_close',
#  'percent_change_next_weeks_price',
#  'days_to_next_dividend',
#  'percent_return_next_dividend']

# %% [markdown]
#  - Verificando o número de linhas e colunas.

# %%
linhas, colunas = df.shape
print(f'Número de linhas: {linhas}')
print(f'Número de colunas: {colunas}')
# Out:
# Número de linhas: 750
# Número de colunas: 16

# %% [markdown]
# Vamos selecionar os valores de abertura, fechamento, máximo e mínimo das ações do McDonalds, listado na Dow Jones como MCD:

# %% [markdown]
#  - Selecionando as linha do dataframe original `df` em que a coluna `stock` é igual a `MCD`.

# %%
df_mcd = df[df['stock'] == 'MCD']

# %% [markdown]
#  - Selecionando apenas as colunas de data e valores de ações.

# %%
df_mcd = df_mcd[['date', 'open', 'high', 'low', 'close']]

# %% [markdown]
# Excelente, o problema é que as colunas com os valores possuem o carater `$` e são do tipo texto (`object` no `pandas`).

# %%
df_mcd.head(n=10)
# Out:
#           date    open    high     low   close
# 216   1/7/2011  $77.10  $77.59  $73.59  $74.37
# 217  1/14/2011  $74.25  $74.49  $72.46  $74.06
# 218  1/21/2011  $74.65  $75.75  $74.31  $75.01
# 219  1/28/2011  $74.25  $75.85  $73.05  $73.28
# 220   2/4/2011  $73.80  $74.50  $73.08  $74.05
# 221  2/11/2011  $74.13  $76.32  $73.30  $76.14
# 222  2/18/2011  $76.07  $76.45  $75.70  $76.13
# 223  2/25/2011  $75.95  $76.45  $74.42  $74.44
# 224   3/4/2011  $74.51  $76.63  $73.64  $76.03
# 225  3/11/2011  $76.38  $77.25  $74.97  $76.73

# %%
df_mcd.dtypes
# Out:
# date     object
# open     object
# high     object
# low      object
# close    object
# dtype: object

# %% [markdown]
# Vamos limpar as colunas com o método `apply`, que permite a aplicação de uma função anônima (`lambda`) qualquer. A função `lambda` remove o caracter **$** e faz a conversão do tipo de `str` para `float`.

# %%
for col in ['open', 'high', 'low', 'close']:
  df_mcd[col] = df_mcd[col].apply(lambda value: float(value.split(sep='$')[-1]))

# %% [markdown]
# Verifique novamente os dados e seus tipos.

# %%
df_mcd.head(n=10)
# Out:
#           date   open   high    low  close
# 216   1/7/2011  77.10  77.59  73.59  74.37
# 217  1/14/2011  74.25  74.49  72.46  74.06
# 218  1/21/2011  74.65  75.75  74.31  75.01
# 219  1/28/2011  74.25  75.85  73.05  73.28
# 220   2/4/2011  73.80  74.50  73.08  74.05
# 221  2/11/2011  74.13  76.32  73.30  76.14
# 222  2/18/2011  76.07  76.45  75.70  76.13
# 223  2/25/2011  75.95  76.45  74.42  74.44
# 224   3/4/2011  74.51  76.63  73.64  76.03
# 225  3/11/2011  76.38  77.25  74.97  76.73

# %%
df_mcd.dtypes
# Out:
# date      object
# open     float64
# high     float64
# low      float64
# close    float64
# dtype: object

# %% [markdown]
# Excelente, agora podemos explorar os dados visualmente.

# %% [markdown]
# **Agora é a sua vez!** Conduza o mesmo processo para extrair e tratar os dados da empresa Coca-Cola (`stock` column igual a `KO`).

# %% [markdown]
#  - Selecionando as linha do dataframe original `df` em que a coluna `stock` é igual a `KO`.

# %%
# Extração e tratamento dos dados da empresa Coca-Cola.

df_ko = df[df['stock'] == 'KO']

# %% [markdown]
# Vamos selecionar os valores de abertura, fechamento, máximo e mínimo das ações da empresa Coca-Cola, listado na Dow Jones como KO:

# %% [markdown]
#  - Selecionando apenas as colunas de data e valores de ações.

# %%
df_ko = df_ko[['date', 'open', 'high', 'low', 'close']]

# %% [markdown]
# Excelente, o problema é que as colunas com os valores possuem o carater `$` e são do tipo texto (`object` no `pandas`).

# %%
# Visualize os dados do dataframe
df_ko.head()
# Out:
#           date    open    high     low   close
# 204   1/7/2011  $65.88  $65.88  $62.56  $62.92
# 205  1/14/2011  $62.70  $63.86  $62.56  $63.13
# 206  1/21/2011  $63.21  $63.92  $62.72  $62.77
# 207  1/28/2011  $62.87  $63.31  $62.14  $62.21
# 208   2/4/2011  $62.32  $63.48  $61.89  $62.56

# %%
# Verifique o tipo dos dados
df_ko.dtypes
# Out:
# date     object
# open     object
# high     object
# low      object
# close    object
# dtype: object

# %% [markdown]
# Vamos limpar as colunas com o método `apply`, que permite a aplicação de uma função anônima (`lambda`) qualquer. A função `lambda` remove o caracter **$** e faz a conversão do tipo de `str` para `float`.

# %%
for col in ['open', 'high', 'low', 'close']:
  df_ko[col] = df_ko[col].apply(lambda value: float(value.split(sep='$')[-1]))

# %% [markdown]
# Verifique novamente os dados e seus tipos.

# %%
# Visualize novamente os dados do dataframe
df_ko.head()
# Out:
#           date   open   high    low  close
# 204   1/7/2011  65.88  65.88  62.56  62.92
# 205  1/14/2011  62.70  63.86  62.56  63.13
# 206  1/21/2011  63.21  63.92  62.72  62.77
# 207  1/28/2011  62.87  63.31  62.14  62.21
# 208   2/4/2011  62.32  63.48  61.89  62.56

# %%
# Verifique novamente o tipo dos dados
df_ko.dtypes
# Out:
# date      object
# open     float64
# high     float64
# low      float64
# close    float64
# dtype: object

# %% [markdown]
# Excelente, agora podemos explorar os dados visualmente.

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Seaborn

# %% [markdown]
# Para visualizar os dados, vamos utilizar o pacote `seaborn` na versão `0.11.1`. A documentação completa por ser encontrada neste [link](https://seaborn.pydata.org/)

# %%
# !pip install seaborn==0.11.1
# Out:
# Collecting seaborn==0.11.1
#   Downloading seaborn-0.11.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn==0.11.1) (1.24.3)
# Requirement already satisfied: scipy>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn==0.11.1) (1.13.0)
# Requirement already satisfied: pandas>=0.23 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn==0.11.1) (2.2.2)
# Requirement already satisfied: matplotlib>=2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn==0.11.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/laurenceribeiro/Library/Python/3.11/lib/python/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/laurenceribeiro/Library/Python/3.11/lib/python/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=0.23->seaborn==0.11.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=0.23->seaborn==0.11.1) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/laurenceribeiro/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.1) (1.16.0)
# Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.11.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Vamos importar o pacote com o apelido (alias) `sns`.

# %%
import seaborn as sns

# %% [markdown]
# Vamos visualizar os valores de abertura das ações ao longo do tempo.

# %%
plot = sns.lineplot(x="date", y="open", data=df_mcd)
_ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)
# Out:
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/723721302.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)

# %% [markdown]
# Vamos também visualizar os valores de fechamento das ações ao longo do tempo.

# %%
plot = sns.lineplot(x="date", y="close", data=df_mcd)
_ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)
# Out:
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/1042705390.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)

# %% [markdown]
# Para facilitar a comparação, vamo visualizar os quatro valores no mesmo gráfico.

# %%
plot = sns.lineplot(x="date", y="value", hue='variable', data=pd.melt(df_mcd, ['date']))
_ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/2651422811.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_mcd['date'], rotation=60)

# %% [markdown]
# Para finalizar, vamos salvar o gráfico numa figura.

# %%
plot.figure.savefig("./mcd.png")

# %% [markdown]
# **Agora é a sua vez,** faça o gráfico acima para a empresa Coca-Cola e salve a imagem com o nome `ko.png`.

# %%
# Visualização dos dados da Coca-Cola.

plot = sns.lineplot(x='date', y='close', data=df_ko)
_ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)
# Out:
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/3600069208.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)

# %% [markdown]
# Vamos visualizar os valores de abertura das ações ao longo do tempo.

# %%
plot = sns.lineplot(x="date", y="open", data=df_ko)
_ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)
# Out:
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/1038399884.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)

# %% [markdown]
# Vamos também visualizar os valores de fechamento das ações ao longo do tempo.

# %%
plot = sns.lineplot(x="date", y="close", data=df_ko)
_ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)
# Out:
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/1979709751.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = plot.set_xticklabels(labels=df_ko['date'], rotation=60)

# %% [markdown]
# Para facilitar a comparação, vamo visualizar os quatro valores no mesmo gráfico.

# %%
plot = sns.lineplot(
    x='date',
    y='value',
    hue='variable',
    data=pd.melt(df_ko, ['date']))
_= plot.set_xticklabels(labels=df_ko['date'], 
    rotation=60)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_core.py:1006: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /var/folders/5j/1xl9_4g17_s_rk9dswvp3d7m0000gn/T/ipykernel_7672/3794726328.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _= plot.set_xticklabels(labels=df_ko['date'],

# %% [markdown]
# Para finalizar, vamos salvar o gráfico numa figura.

# %%
plot.figure.savefig('./ko.png')

# %% [markdown]
# Analise as duas imagens e escreva pelo menos um *insight* que você consegue extrair dos dados. Fique a vontade para escrever quantos *insights* você quiser.

# %% [markdown]
# Obs: *Insights* são observações sobre o que você percebe/entende/interpreta em suas análises. No caso deste exercício, você vai analisar os dados dos gráficos da empresa McDonalds e da empresa Cola-Cola e notar o que os dados gerados podem ser interessante, que tipo de interpretação o comportamento dos dados estão te trazendo.

# %% [markdown]
# **Insight #1**: Na primeira semana do ano tivemos uma queda no mercado de ação da Coca-Cola.
#
# **Insight #2**: No início do mês de Março, as ações valorizaram significativamente, mantendo uma alta frequência um pouco mais da metade do mês de abril.

# %% [markdown]
# ---
