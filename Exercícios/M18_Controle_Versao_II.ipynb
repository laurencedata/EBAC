# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Controle de Versão II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Adicionar e salvar;</li>
#   <li>Visualizar e reverter;</li>
#   <li>Persistir e atualizar.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Setup

# %% [markdown]
# Para realizar os exercicios vamos configurar o `git` e trazer o projeto do GitHub para a a máquina virtual do Google Colab (ou na sua máquina local, as instruções são as mesmas). Para tanto, replique as atividades expostas na aula 1 deste módulo.

# %% [markdown]
# ### **1.1. Autenticação**

# %% [markdown]
# Nesta etapa, vamos configura o `git` com suas credenciais.

# %%
import os

username = "laurence-data" # insira o seu nome de usuário do git
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken

# %% [markdown]
# ### **1.2. Projeto**

# %% [markdown]
# Nesta etapa, vamos trazer o projeto do GitHub para máquina local.

# %%
# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/laurencedata/da-ebac.git # insira o link do seu repositório remoto
# Out:
# Cloning into 'da-ebac'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 5), reused 8 (delta 1), pack-reused 0
# Receiving objects: 100% (18/18), 62.01 KiB | 112.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# verificando o repositório no local correto

# !pwd
# Out:
# /Users/laurenceribeiro/Library/Mobile Documents/com~apple~CloudDocs/Dados /Analista de Dados - EBAC/AdD - Histórico Completo/M18

# %%
# insira o nome do seu repositório
# %cd /Users/laurenceribeiro/Documents/laurenceribeiro/Exercicios_EBAC/M18/da-ebac
# Out:
# /Users/laurenceribeiro/Documents/laurenceribeiro/Exercicios_EBAC/M18/da-ebac

# %%
# conferindo novamente o repositório atualizado

# !pwd
# Out:
# /Users/laurenceribeiro/Documents/laurenceribeiro/Exercicios_EBAC/M18/da-ebac

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Preço da gasolina

# %% [markdown]
# O código abaixo gera um arquivo com o preço médio de venda da gasolina na cidade de São Paulo nos 10 primeiros dias de Julho de 2021.

# %%
# %%writefile gasolina.csv
# dia,venda
# 1,5.11
# 2,4.99
# 3,5.02
# 4,5.21
# 5,5.07
# 6,5.09
# 7,5.13
# 8,5.12
# 9,4.94
# 10,5.03
# Out:
# Overwriting gasolina.csv

# %% [markdown]
# ### **2.1. Desenvolvimento**

# %% [markdown]
# Gere uma gráfico de linha utilizando os dados do arquivo `gasolina.csv` com o dia no eixo `x` e o seu preço no eixo `y` utilizando os pacotes Python de sua preferência, como o Pandas e o Seaborn. Salve o gráfico no arquivo `gasolina.png` e o seu código Python de geração no arquivo `gasolina.py`.

# %%
# código de geração do gráfico 

# importando as bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# leitura da tabela no Pandas
gasolina = pd.read_csv("gasolina.csv")

# criando o gráfico de linhas

plt.figure(figsize=(8, 6))
plt.xticks(rotation=45)
sns.set_theme(style="darkgrid")
sns.lineplot(data=gasolina, x="dia", y="venda", color="red")
plt.title("Preço da Gasolina nos últimos 10 dias")
plt.show()

# %% [markdown]
# ### **2.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" os arquivos gerados (base, código Python e gráfico).

# %%
# comandos git para adicionar e commitar os arquivos

# !touch gasolina.py
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### **2.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# comandos git para enviar o commit para o GitHub

# !git add gasolina.py
# !git add gasolina.csv
# !git add gasolina.png
# !git add gasolina.py
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Adicionando o arquivo ipynb
# !git add gasolina.ipynb
# !git commit -m "Arquivo gasolina.ipynb adicionado"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m "Alteração"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# publicando no GitHub
# !git push origin main
# !git status
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/laurencedata/da-ebac.git/'
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# verificando o status novamente
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Arquivo README.md

# %% [markdown]
# O arquivo README.md é a porta de entrada do seu projeto, é ele que será renderizado quando o seu projeto for acessado, portanto, é importante que ele esteja bem escrito. Alguns exemplos:

# %% [markdown]
#  - [Pandas](https://github.com/pandas-dev/pandas);
#  - [Seaborn](https://github.com/mwaskom/seaborn);
#  - [Spark Cluster on Docker](https://github.com/cluster-apps-on-docker/spark-standalone-cluster-on-docker), esse projeto é meu! :)

# %% [markdown]
# ### **3.1. Desenvolvimento**

# %% [markdown]
# Altere o arquivo README.md com informações sobre seu repositório, inclua um título e uma breve descrição do repositório (no mínimo).

# %% [markdown]
# > **Dica**: o README.md pode ser configurado utilizando o padrão **markdown**, o mesmo que utilizamos nas células de texto aqui no Google Colab.

# %% [markdown]
# ### **3.2. Git**

# %% [markdown]
# Utilizando os comandos do `git`, adicione e "commite" as alterações no arquivo `README.md`.

# %%
# checando a alteração do arquivo

# !git status #
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# comandos git para adicionar e commitar os arquivos

# !git add README.md

# %%
# checando novamente o arquivo modificado

# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Descrição no README.md adicionada"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ### **3.3. Github**

# %% [markdown]
# Utilizando os comandos do `git`, envie o seu commit para o GitHub.

# %%
# comandos git para enviar o commit para o GitHub

# !git add README.md
# !git commit -m "Descrição no README.md adicionada"
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# publicando no GitHub

# !git push origin main
# !git status
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/laurencedata/da-ebac.git/'
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
